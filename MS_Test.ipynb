# %%
from glob import glob
import matplotlib.pylab as plt

import pydicom as dicom

# %%
path = '/Users/eridon/Desktop/lol/LongitudinalMultipleSclerosisLesionSegmentationChallengeMiccai21/training/026/flair_time01_on_middle_space.nii'

# %%
img = nib.load(path).get_fdata()
img.shape
# Out:
# (144, 192, 192)

# %%
print(f"The .nii files are stored in memory as numpy's: {type(img)}.")
# Out:
# The .nii files are stored in memory as numpy's: <class 'numpy.memmap'>.

# %%
plt.style.use('default')
fig, axes = plt.subplots(4,4, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    ax.imshow(img[:,:,1 + i])
plt.show()

# %%
img.shape
# Out:
# (144, 192, 192)

# %%
from skimage.transform import rotate

plt.style.use('default')
fig, axes = plt.subplots(4,4, figsize=(12,12))
for i, ax in enumerate(axes.reshape(-1)):
    img_rot = rotate(img[:,:,1 + i], -90)
    ax.imshow(img_rot)
plt.show()
